# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dataframe_image as dfi

# %%
covid_data = pd.read_csv('input/covid19_fullgrouped.csv')
covid_data["Date"] = pd.to_datetime(covid_data['Date'])
covid_data['YearMonth'] = covid_data['Date'].map(lambda date: 100*date.year + date.month)
covid_data
# Out:
#             Date             Country  Confirmed  Deaths  Recovered  Active  \
# 0     2020-01-22         Afghanistan          0       0          0       0
# 1     2020-01-22             Albania          0       0          0       0
# 2     2020-01-22             Algeria          0       0          0       0
# 3     2020-01-22             Andorra          0       0          0       0
# 4     2020-01-22              Angola          0       0          0       0
# ...          ...                 ...        ...     ...        ...     ...
# 35151 2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152 2020-07-27      Western Sahara         10       1          8       1
# 35153 2020-07-27               Yemen       1691     483        833     375
# 35154 2020-07-27              Zambia       4552     140       2815    1597
# 35155 2020-07-27            Zimbabwe       2704      36        542    2126
#
# ...

# %%
covid_d = covid_data.query('YearMonth == 202004')
covid_d
# Out:
#             Date             Country  Confirmed  Deaths  Recovered  Active  \
# 13090 2020-04-01         Afghanistan        237       4          5     228
# 13091 2020-04-01             Albania        259      15         67     177
# 13092 2020-04-01             Algeria        847      58         61     728
# 13093 2020-04-01             Andorra        390      14         10     366
# 13094 2020-04-01              Angola          8       2          1       5
# ...          ...                 ...        ...     ...        ...     ...
# 18695 2020-04-30  West Bank and Gaza        344       2         76     266
# 18696 2020-04-30      Western Sahara          6       0          5       1
# 18697 2020-04-30               Yemen          6       2          1       3
# 18698 2020-04-30              Zambia        106       3         55      48
# 18699 2020-04-30            Zimbabwe         40       4          5      31
#
# ...

# %%
covid_c = covid_d.groupby('Country')['Active'].max().reset_index()
covid_c_sorted = covid_c.sort_values('Active',ascending=False).reset_index(drop=True)
covid_most_patient = covid_c_sorted.head(9)
dfi.export(covid_most_patient,'output/most_covid19_patients.png',table_conversion="matplotlib")

# %% [markdown]
# #### Death Rate in Iran

# %%
# covid_data['Country'] = covid_data.query()
covid_d4_ir = covid_data.query('YearMonth == 202004 and Country=="Iran"').reset_index(drop=True)

fig, ax = plt.subplots(figsize=(12,6))

ax.stackplot(covid_d4_ir["Date"],covid_d4_ir["New cases"].to_numpy(),color='skyblue')
ax.stackplot(covid_d4_ir["Date"],covid_d4_ir["New deaths"].to_numpy(),color='darkorange')


plt.title('Death Rate in Iran per day')
fig.tight_layout()
fig.savefig('output/iran_death_rate.png')
covid_d4_ir
# Out:
#          Date Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-04-01    Iran      47593    3036      15473   29084       2988
# 1  2020-04-02    Iran      50468    3160      16711   30597       2875
# 2  2020-04-03    Iran      53183    3294      17935   31954       2715
# 3  2020-04-04    Iran      55743    3452      19736   32555       2560
# 4  2020-04-05    Iran      58226    3603      19736   34887       2483
# 5  2020-04-06    Iran      60500    3739      24236   32525       2274
# 6  2020-04-07    Iran      62589    3872      27039   31678       2089
# 7  2020-04-08    Iran      64586    3993      29812   30781       1997
# 8  2020-04-09    Iran      66220    4110      32309   29801       1634
# 9  2020-04-10    Iran      68192    4232      35465   28495       1972
# 10 2020-04-11    Iran      70029    4357      41947   23725       1837
# 11 2020-04-12    Iran      71686    4474      43894   23318       1657
# ...
